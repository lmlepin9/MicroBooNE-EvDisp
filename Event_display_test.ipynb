# %%
# %matplotlib widget
from EventDisplay import EvDisp

# %%
run=16888
subrun=116
event=5850

# %%
EvDisp(run,subrun,event,0,'mc')
# Out:
# 1782
# 1782
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
